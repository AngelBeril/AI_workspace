# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
inputNumber1 =10
inputNumber2=30
print(f"Num1= {inputNumber1} \n Num2= {inputNumber2}")
additionResult = inputNumber1 + inputNumber2
print("Add= ",additionResult)
# Out:
# Num1= 10
#  Num2= 30
# Add=  40

# %%
inputNumber1 =10
inputNumber2=30
print("Num1= {} \n Num2= {}".format(inputNumber1,inputNumber2))
additionResult = inputNumber1 + inputNumber2
print("Add= ",additionResult)
# Out:
# Num1= 10
#  Num2= 30
# Add=  40
