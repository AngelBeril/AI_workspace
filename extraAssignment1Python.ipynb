# %%
#print statement

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy input

# %%
instituteName = input("Enter your institute name? : ")
# Out:
# Enter your institute name? :  HOPE AI

# %%
#Buy inputs

# %%
studentName = input("Enter your name: ")
studentAge = int(input("Enter your age: "))
schoolName = input("Enter your school name: ")
degree = input("Enter your degree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru school
# Enter your degree:  B.E CSE

# %%
#Addition

# %%
a = int(input("a= "))
b = int(input("b= "))
additionResult = a + b
print(f"add = {additionResult}")
# Out:
# a=  43
# b=  34
# add = 77

# %%
#Subtraction

# %%
subtractionResult = a - b
print(f"sub = {subtractionResult}")
# Out:
# sub = 9

# %%
a = int(input("a= "))
b = int(input("b= "))
multiplicationResult = a * b
print(f"mul = {multiplicationResult}")
# Out:
# a=  63
# b=  97
# mul = 6111

# %%
a = int(input("a= "))
b = int(input("b= "))
divisionResult = a / b
print(f"div = {divisionResult}")
# Out:
# a=  76
# b=  31
# div = 2.4516129032258065

# %%
#Floor Division

# %%
from math import floor
floorResult = a / b
print(f"Floor Div = {floor(floorResult)}")
# Out:
# Floor Div = 2

# %%
#Modulo

# %%
moduloResult = a % b
print(f"div = {moduloResult}")
# Out:
# div = 14

# %%
#power

# %%
a = int(input("a= "))
b = int(input("b= "))
powerResult = pow (a,b)
print(f"Power = {powerResult}")
# Out:
# a=  4
# b=  4
# Power = 256
